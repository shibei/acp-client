# %%
import requests
import bs4 as bs

# %%
response = requests.get("http://27056t89i6.wicp.vip:1011/index.asp",auth=('share','1681'))
html_str = response.text

# %%
bsoup = bs.BeautifulSoup(html_str, 'html.parser')
bsoup.find_all('title')[0].text
# Out:
# ' TSQ01 free use telescope check xjlk.net - Welcome share '
